# %% [markdown]
# <a href="https://colab.research.google.com/github/M-SrinivasYadav/VIRTUAL_DATA_SCIENCE/blob/main/create_csv_Read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
d={'Names':['Dastaiah','Narendhar','Suguna','Chandra_Leela','Pooja','Pradeeptha','Nisha','Chintu'],
   'Date_of_Birth':['April_10','July_4','January_1','july_2','July_10','April_2','August_26','August_18'],
   'Age':[44,48,42,44,24,18,21,22],
   'Blood_group':['o+','o+','o+','o+','B+','B+','B+','B+'],
   'Height':[5.5,5.5,5.2,5.2,5.2,5.2,5.4,5.6],
   'Weight':[80,80,50,50,52,52,52,53]}
Family=pd.DataFrame(d)
print(Family)
Family.to_csv("Family.CSV")
# Out:
#            Names Date_of_Birth  Age Blood_group  Height  Weight
# 0       Dastaiah      April_10   44          o+     5.5      80
# 1      Narendhar        July_4   48          o+     5.5      80
# 2         Suguna     January_1   42          o+     5.2      50
# 3  Chandra_Leela        july_2   44          o+     5.2      50
# 4          Pooja       July_10   24          B+     5.2      52
# 5     Pradeeptha       April_2   18          B+     5.2      52
# 6          Nisha     August_26   21          B+     5.4      52
# 7         Chintu     August_18   22          B+     5.6      53

# %%
import pandas as pd
excel=pd.read_excel("/content/FamilyDataset.xlsx")
excel
# Out:
#            Name  Date of Birth  Age Blood Group  Height  Weight
# 0       Dastaiah    2010-04-01   44          O+     5.5      80
# 1      Narendhar    2004-07-01   48          O+     5.5      80
# 2         Suguna    2001-01-01   42          O+     5.2      50
# 3  Chandra leela    2002-07-01   44          O+     5.2      50
# 4          Pooja    2010-07-01   24          B+     5.2      52
# 5     Pradeeptha    2002-04-01   18          B+     5.2      52
# 6          Nisha    2026-08-01   21          B+     5.4      52
# 7         Chintu    2018-08-01   22          B+     5.6      53

# %%
import pandas as pd
csv1=pd.read_csv("/content/FamilyDataset.csv")
csv1
# Out:
#            Name  Date of Birth  Age Blood Group  Height  Weight
# 0       Dastaiah        Apr-10   44          O+     5.5      80
# 1      Narendhar        Jul-04   48          O+     5.5      80
# 2         Suguna        Jan-01   42          O+     5.2      50
# 3  Chandra leela        Jul-02   44          O+     5.2      50
# 4          Pooja        Jul-10   24          B+     5.2      52
# 5     Pradeeptha        Apr-02   18          B+     5.2      52
# 6          Nisha        Aug-26   21          B+     5.4      52
# 7         Chintu        Aug-18   22          B+     5.6      53
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# csv1['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# csv1['Height'].plot(kind='hist', bins=20, title='Height')
# ...
